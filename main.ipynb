# %%
 # Import of all functions and libraries from the project.
from companies_collection import *
from suitable_cities import *
from paris_geoqueries import *
from ponderation import *

# %% [markdown]
# # COMPANIES COLLECTION (MONGO DB)

# %%
client = MongoClient('localhost:27017')
db = client.get_database('ironhack')
companies = db.get_collection('companies')

# %%
companies = mongo('ironhack', 'companies') # we get companies collection from mongo

# %%
collection_queried (companies) # asks what company categories to keep and money raised minimum, exports a json file (¡¡¡Remove last comma from it!!!)
# Out:
# 'The collection has been exported, with a total remaining of 114 companies!'

# %% [markdown]
# # SUITABLE CITIES

# %%
queried_db = json_load('queried_db.json') # we import the json from previous query (REMOVE COMMA!)

# %%
offices_df = companies_distribution(queried_db)

# %%
df_info(offices_df)
# Out:
# The companies with most offices are Nexway, Clear2Pay and EnOcean, with 13, 7 and 4 offices respectively.
# The cities with the most offices are London, Paris and Edinburgh, with 17, 15 and 6 offices respectively.
# The 47.82608695652174% of latitude cells are empty.
# The 47.82608695652174% of longitude cells are empty.

# %%
map_office_distribution(offices_df) # plotted coordinates of offices that fulfill query requirements.
# Out:
# The cities with the most offices are
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %%
city_count(offices_df) # city distribution of all offices (with/without coordinates).

# In this case, the suitable city turns out to be Paris. In case of different query results, get the correspondent geojson.
# Out:
# The most suitable cities are London and Paris, with 17 and 15 offices respectively
#         city  count
# 0     London     17
# 1      Paris     15
# 2  Edinburgh      6
# 3     Madrid      5
# 4     Berlin      4

# %% [markdown]
# # PARIS GEOQUERIES

# %%
load_dotenv()
# Out:
# True

# %%
foursquare_key = os.getenv('fsq_key') # Foursquare key to get API queries.

# %%
client = MongoClient('localhost:27017') # Paris collection from geojson uploaded in MongoDB (without feature, meaning that Mongo has a collection for every district).
db = client.get_database('ironhack')
paris = db.get_collection('paris')
paris = list(paris.find())

# %%
with open('feature.geojson') as geo_file: # with feature, meaning that a single collection contains all districts!!!
    geo_feature = json.load(geo_file)

# %%
area_info = arrondissement_scraping() # Area of each Paris' district.
area_info
# Out:
# /Users/gerardrius/Ironhack/projects/Gerard-Project-III/paris_geoqueries.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   districts_area.rename(columns={'Area (km  2  )': 'Area'}, inplace = True, errors = 'raise')
# /Users/gerardrius/Ironhack/projects/Gerard-Project-III/paris_geoqueries.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   districts_area.sort_values(by = ['Name'], ascending = True, inplace = True)
#                    Name     Area
# 0   Batignolles-Monceau   5.6690
# 1                Bourse   1.3975
# 2      Butte-Montmartre   6.0050
# 3       Buttes-Chaumont   6.7860
# 4              Entrepôt   2.8920
# 5              Gobelins   7.1460
# 6        Hôtel-de-Ville   1.3975
# 7                Louvre   1.3975
# 8            Luxembourg   2.1540
# 9          Ménilmontant   5.9840
# 10         Observatoire   5.6210
# 11                Opéra   2.1790
# 12       Palais-Bourbon   4.0880
# 13             Panthéon   2.5410
# 14                Passy  16.3050
# 15           Popincourt   3.6660
# 16              Reuilly  16.3240
# 17               Temple   1.3975
# 18            Vaugirard   8.5020
# 19               Élysée   3.8810

# %% [markdown]
# ## Definition of most important functions (imported from paris_geoqueries):
# ### Density functions
# - foursquare_query (query, category, place, limit=10)
# - spot_finder (df), the one returned from foursquare_query function
#
# ### Distance functions
# - distance_criteria (query, category) a string and category code
#
# ### Plot function
# - district_distribution (count_df) -> plots df with district and a single variable count in Paris map.

# %%
# Some examples of use of these functions below:
vegan_query = foursquare_query('Vegan', 13377, 'Paris', 50)
vegan_density = spot_finder(vegan_query)

# %%
vegan_query
# Out:
#                    Coordinates                               Name  \
# 0   POINT (2.348476 48.852044)           Le Grenier de Notre Dame
# 1   POINT (2.341756 48.853268)                       Chez Germain
# 2   POINT (2.346294 48.857952)  Dernier Bar Avant la Fin du Monde
# 3   POINT (2.353504 48.848705)                Le Puits de Légumes
# 4   POINT (2.358614 48.855997)                        Jak Healthy
# 5   POINT (2.338339 48.854195)                          Sense eat
# 6   POINT (2.345682 48.860489)               Saveurs Végét'Halles
# 7   POINT (2.345376 48.860694)  Le Bio d'Adam et Eve Saint-Honoré
# 8    POINT (2.36235 48.852735)               Le Potager du Marais
# 9   POINT (2.349702 48.843427)                      Vegan Folie's
# 10  POINT (2.352809 48.864156)                            Riz Riz
# 11  POINT (2.365715 48.856502)                          Juice Lab
# 12   POINT (2.35667 48.863713)                    Wild & The Moon
# 13   POINT (2.366714 48.85191)                      Grand Appétit
# 14  POINT (2.353793 48.865068)                         VegEateria
# 15  POINT (2.367256 48.852804)                        Café Ginger
# 16  POINT (2.345739 48.865832)                          Wholywood
# 17  POINT (2.343656 48.865803)           Gaby Super Natural Vegan
# 18  POINT (2.351642 48.866562)                      Furahaa To Go
# 19  POINT (2.351343 48.866739)                   Spirulina Coffee
# 20  POINT (2.348601 48.867856)                      Kapunka Vegan
# 21  POINT (2.349286 48.867993)                         Avocateria
# 22  POINT (2.371346 48.852315)                       Végé'Saveurs
# 23  POINT (2.343566 48.867925)                             Bioboa
# 24   POINT (2.343789 48.86886)                               Mopa
# 25   POINT (2.33499 48.866269)                         On The Bab
# 26  POINT (2.371544 48.847254)          Le Cremieux (Le Crémieux)
# 27   POINT (2.36635 48.864921)             Wild & The Moon Amelot
# 28  POINT (2.373454 48.857632)                   Le Grand Breguet
# 29  POINT (2.374595 48.850157)                    Comptoir Veggie
# 30  POINT (2.325482 48.845313)                      Copper Branch
# 31  POINT (2.336196 48.869003)                             Vegeta
# 32   POINT (2.375537 48.85341)                     Lotus & Cactus
# 33  POINT (2.374674 48.858934)                 Aujourd'hui Demain
# 34  POINT (2.373175 48.861708)                  East Side Burgers
# 35  POINT (2.377733 48.857314)               The Friendly Kitchen
# 36  POINT (2.352987 48.873102)             Jah Jah By le Tricycle
# 37  POINT (2.344505 48.873304)                           Vegebowl
# 38  POINT (2.360485 48.871987)                    Bob's Juice Bar
# 39  POINT (2.370188 48.868127)  Soya Végétarien Végétalien et Bio
# 40  POINT (2.369075 48.870262)                         Tien Hiang
# 41  POINT (2.369075 48.870262)                               Thai
# 42  POINT (2.363137 48.873239)                        Sol Semilla
# 43  POINT (2.363096 48.873261)                             Plan d
# 44  POINT (2.336035 48.874378)                              3 Bio
# 45  POINT (2.345848 48.876226)                       Veggie Tasty
# 46   POINT (2.33138 48.873372)        Créatures par Julien Sebbag
# 47   POINT (2.32737 48.872719)                        Yem'a Paris
# 48   POINT (2.324498 48.83575)                     Sweet Rawmance
# 49  POINT (2.348988 48.877573)                          42 Degrés
#
#                                Type
# 0   Vegan and Vegetarian Restaurant
# 1   Vegan and Vegetarian Restaurant
# 2   Vegan and Vegetarian Restaurant
# 3   Vegan and Vegetarian Restaurant
# 4   Vegan and Vegetarian Restaurant
# 5   Vegan and Vegetarian Restaurant
# 6   Vegan and Vegetarian Restaurant
# 7   Vegan and Vegetarian Restaurant
# 8   Vegan and Vegetarian Restaurant
# 9   Vegan and Vegetarian Restaurant
# 10  Vegan and Vegetarian Restaurant
# 11  Vegan and Vegetarian Restaurant
# 12  Vegan and Vegetarian Restaurant
# 13  Vegan and Vegetarian Restaurant
# 14  Vegan and Vegetarian Restaurant
# 15  Vegan and Vegetarian Restaurant
# 16  Vegan and Vegetarian Restaurant
# 17  Vegan and Vegetarian Restaurant
# 18  Vegan and Vegetarian Restaurant
# 19  Vegan and Vegetarian Restaurant
# 20  Vegan and Vegetarian Restaurant
# 21  Vegan and Vegetarian Restaurant
# 22  Vegan and Vegetarian Restaurant
# 23  Vegan and Vegetarian Restaurant
# 24  Vegan and Vegetarian Restaurant
# 25  Vegan and Vegetarian Restaurant
# 26  Vegan and Vegetarian Restaurant
# 27  Vegan and Vegetarian Restaurant
# 28  Vegan and Vegetarian Restaurant
# 29  Vegan and Vegetarian Restaurant
# 30  Vegan and Vegetarian Restaurant
# 31  Vegan and Vegetarian Restaurant
# 32  Vegan and Vegetarian Restaurant
# 33  Vegan and Vegetarian Restaurant
# 34  Vegan and Vegetarian Restaurant
# 35  Vegan and Vegetarian Restaurant
# 36  Vegan and Vegetarian Restaurant
# 37  Vegan and Vegetarian Restaurant
# 38  Vegan and Vegetarian Restaurant
# 39  Vegan and Vegetarian Restaurant
# 40  Vegan and Vegetarian Restaurant
# 41  Vegan and Vegetarian Restaurant
# 42  Vegan and Vegetarian Restaurant
# 43  Vegan and Vegetarian Restaurant
# 44  Vegan and Vegetarian Restaurant
# 45  Vegan and Vegetarian Restaurant
# 46  Vegan and Vegetarian Restaurant
# 47  Vegan and Vegetarian Restaurant
# 48  Vegan and Vegetarian Restaurant
# 49  Vegan and Vegetarian Restaurant

# %%
district_distribution(vegan_density)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52accacf664ed217838e0a7f9f38112a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52accacf664ed217838e0a7f9f38112a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52accacf664ed217838e0a7f9f38112a = L.map(
#                 &quot;map_52accacf664ed217838e0a7f9f38112a&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0e657f83cafa9e673b11bc10e6d210a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52accacf664ed217838e0a7f9f38112a);
#
#
#             var choropleth_477e03d2c80b171077ed23abfd07a869 = L.featureGroup(
#                 {}
#             ).addTo(map_52accacf664ed217838e0a7f9f38112a);
#
#
#         function geo_json_01e755a3a34d401d15fd62a48f7660e6_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Temple&quot;: case &quot;Op\u00e9ra&quot;: case &quot;Louvre&quot;: case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Panth\u00e9on&quot;: case &quot;Luxembourg&quot;: case &quot;Enclos-St-Laurent&quot;: case &quot;Popincourt&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_01e755a3a34d401d15fd62a48f7660e6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_01e755a3a34d401d15fd62a48f7660e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_01e755a3a34d401d15fd62a48f7660e6_onEachFeature,
#
#                 style: geo_json_01e755a3a34d401d15fd62a48f7660e6_styler,
#         });
#
#         function geo_json_01e755a3a34d401d15fd62a48f7660e6_add (data) {
#             geo_json_01e755a3a34d401d15fd62a48f7660e6
#                 .addData(data)
#                 .addTo(choropleth_477e03d2c80b171077ed23abfd07a869);
#         }
#             geo_json_01e755a3a34d401d15fd62a48f7660e6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 48.84], [2.351799, 48.83675]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 5, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Panth\u00e9on&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:34.699Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;:

# %%
starbucks_query = foursquare_query('Starbucks', 13035, 'Paris', 50)
starbucks_density = spot_finder(starbucks_query)

# %%
district_distribution(starbucks_density)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d430e249d294e4900ca3f470a164da0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d430e249d294e4900ca3f470a164da0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d430e249d294e4900ca3f470a164da0 = L.map(
#                 &quot;map_9d430e249d294e4900ca3f470a164da0&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f47439caf2a1462c4f6fba0adfd96cb1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d430e249d294e4900ca3f470a164da0);
#
#
#             var choropleth_00346d655cec279ef810eec1cc1c2244 = L.featureGroup(
#                 {}
#             ).addTo(map_9d430e249d294e4900ca3f470a164da0);
#
#
#         function geo_json_5d9b8a4380308077cc67256e3d2430a6_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;: case &quot;\u00c9lys\u00e9e&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Panth\u00e9on&quot;: case &quot;Enclos-St-Laurent&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Op\u00e9ra&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Louvre&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5d9b8a4380308077cc67256e3d2430a6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5d9b8a4380308077cc67256e3d2430a6 = L.geoJson(null, {
#                 onEachFeature: geo_json_5d9b8a4380308077cc67256e3d2430a6_onEachFeature,
#
#                 style: geo_json_5d9b8a4380308077cc67256e3d2430a6_styler,
#         });
#
#         function geo_json_5d9b8a4380308077cc67256e3d2430a6_add (data) {
#             geo_json_5d9b8a4380308077cc67256e3d2430a6
#                 .addData(data)
#                 .addTo(choropleth_00346d655cec279ef810eec1cc1c2244);
#         }
#             geo_json_5d9b8a4380308077cc67256e3d2430a6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 4

# %% [markdown]
# # PONDERATION
# ## Normalization function
#
# density_or_points_normalizer (df, query)
#
# Explanation:
# Normalizes all values of distance or density between 0 and 1. In density, the higher it is, the closer to 1; in distance, the shortest, the closest to 1.
#
# The highest value will get a 1, the lowest a 0. Intermediate values are distributed within the proportion between original min and max.

# %%
# Airports
airport_query = distance_criteria ('Airport', 19040)
airport_normalized = density_or_points_normalizer(airport_query, 'Airports')

# %%
airport_query
# Out:
#                District  Distance
# 0   Batignolles-Monceau    -18090
# 1                Bourse    -15582
# 2      Butte-Montmartre    -18216
# 3       Buttes-Chaumont    -17585
# 4     Enclos-St-Laurent    -16383
# 5              Gobelins    -11091
# 6        Hôtel-de-Ville    -13959
# 7                Louvre    -15009
# 8            Luxembourg    -13567
# 9          Ménilmontant    -15208
# 10         Observatoire    -11528
# 11                Opéra    -16605
# 12       Palais-Bourbon    -14642
# 13             Panthéon    -12893
# 14                Passy    -16424
# 15           Popincourt    -14537
# 16              Reuilly    -12531
# 17               Temple    -14908
# 18            Vaugirard    -13441
# 19               Élysée    -16443

# %%
# Dog hairdresser
dog_grooming_query = distance_criteria ('', 11134)
dog_grooming_normalized = density_or_points_normalizer(dog_grooming_query, 'Dog grooming')

# %%
dog_grooming_query
# Out:
#                District  Distance
# 0   Batignolles-Monceau      -277
# 1                Bourse     -2486
# 2      Butte-Montmartre      -296
# 3       Buttes-Chaumont      -791
# 4     Enclos-St-Laurent     -2033
# 5              Gobelins     -2999
# 6        Hôtel-de-Ville     -2442
# 7                Louvre     -2151
# 8            Luxembourg      -662
# 9          Ménilmontant     -2027
# 10         Observatoire     -1611
# 11                Opéra     -1641
# 12       Palais-Bourbon      -971
# 13             Panthéon     -1643
# 14                Passy     -2708
# 15           Popincourt     -2414
# 16              Reuilly     -1628
# 17               Temple     -3131
# 18            Vaugirard     -2019
# 19               Élysée     -1107

# %%
# Basketball courts
basketball_query = distance_criteria ('Basket', 18008)
basketball_normalized = density_or_points_normalizer(basketball_query, 'Basket Court')

# %%
basketball_query
# Out:
#                District  Distance
# 0   Batignolles-Monceau     -2112
# 1                Bourse     -1630
# 2      Butte-Montmartre      -933
# 3       Buttes-Chaumont     -1018
# 4     Enclos-St-Laurent     -1788
# 5              Gobelins     -3093
# 6        Hôtel-de-Ville     -1775
# 7                Louvre     -2172
# 8            Luxembourg     -1511
# 9          Ménilmontant     -1788
# 10         Observatoire     -1053
# 11                Opéra      -571
# 12       Palais-Bourbon     -1509
# 13             Panthéon     -2341
# 14                Passy      -666
# 15           Popincourt      -690
# 16              Reuilly     -2337
# 17               Temple     -1939
# 18            Vaugirard     -1841
# 19               Élysée     -1977

# %%
# Elementary schools
schools_query = foursquare_query('School', 12058, 'Paris', 50)
school_density = spot_finder(schools_query)
school_normalized = density_or_points_normalizer(school_density, 'Schools')

# %%
# Vegan restaurants
vegan_query = foursquare_query('Vegan', 13377, 'Paris', 50)
vegan_density = spot_finder(vegan_query)
vegan_normalized = density_or_points_normalizer(vegan_density, 'Vegan restaurants')

# %%
# Starbucks
starbucks_query = foursquare_query('Starbucks', 13035, 'Paris', 50)
starbucks_density = spot_finder(starbucks_query)
starbucks_normalized = density_or_points_normalizer(starbucks_density, 'Starbucks')

# %%
# Ratings per district
ponderation = ponderation_classification()
ponderation
# Out:
# /Users/gerardrius/Ironhack/projects/Gerard-Project-III/ponderation.py:48: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   area_info['Sums'] = area_info.sum(axis=1)
#                    Name      Sums
# 0   Batignolles-Monceau  1.600258
# 1                Bourse  2.575778
# 2      Butte-Montmartre  1.896350
# 3       Buttes-Chaumont  2.048641
# 4              Entrepôt  2.047284
# 5              Gobelins  1.236077
# 6        Hôtel-de-Ville  2.405935
# 7                Louvre  2.603114
# 8            Luxembourg  3.361137
# 9          Ménilmontant  1.326447
# 10         Observatoire  2.740689
# 11                Opéra  3.192497
# 12       Palais-Bourbon  2.350071
# 13             Panthéon  2.181881
# 14                Passy  1.461133
# 15           Popincourt  2.093127
# 16              Reuilly  1.853264
# 17               Temple  1.366299
# 18            Vaugirard  1.720609
# 19               Élysée  2.248892

# %% [markdown]
# # Final results

# %%
district_distribution(starbucks_density)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c090d6eea5a772901c8fcef2775407 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c090d6eea5a772901c8fcef2775407&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c090d6eea5a772901c8fcef2775407 = L.map(
#                 &quot;map_31c090d6eea5a772901c8fcef2775407&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fb6e2b981b5b7687f7cfd9f3eef8c68 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31c090d6eea5a772901c8fcef2775407);
#
#
#             var choropleth_d206a23064019ce830fd4b78db84f43c = L.featureGroup(
#                 {}
#             ).addTo(map_31c090d6eea5a772901c8fcef2775407);
#
#
#         function geo_json_3974e72c318a087a8dc68f0ed4c74835_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;: case &quot;\u00c9lys\u00e9e&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Panth\u00e9on&quot;: case &quot;Enclos-St-Laurent&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Op\u00e9ra&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Louvre&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_3974e72c318a087a8dc68f0ed4c74835_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3974e72c318a087a8dc68f0ed4c74835 = L.geoJson(null, {
#                 onEachFeature: geo_json_3974e72c318a087a8dc68f0ed4c74835_onEachFeature,
#
#                 style: geo_json_3974e72c318a087a8dc68f0ed4c74835_styler,
#         });
#
#         function geo_json_3974e72c318a087a8dc68f0ed4c74835_add (data) {
#             geo_json_3974e72c318a087a8dc68f0ed4c74835
#                 .addData(data)
#                 .addTo(choropleth_d206a23064019ce830fd4b78db84f43c);
#         }
#             geo_json_3974e72c318a087a8dc68f0ed4c74835_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 4

# %%
district_distribution(vegan_density)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3146cdf9c6e38dfda822697befbc62e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3146cdf9c6e38dfda822697befbc62e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3146cdf9c6e38dfda822697befbc62e = L.map(
#                 &quot;map_f3146cdf9c6e38dfda822697befbc62e&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_624063d344397f5ae880e2b41f4f88a2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f3146cdf9c6e38dfda822697befbc62e);
#
#
#             var choropleth_bec061c6686048470f0505442601b898 = L.featureGroup(
#                 {}
#             ).addTo(map_f3146cdf9c6e38dfda822697befbc62e);
#
#
#         function geo_json_cf6d43f8745b7fab84b1b88da14d59b3_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Temple&quot;: case &quot;Op\u00e9ra&quot;: case &quot;Louvre&quot;: case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Panth\u00e9on&quot;: case &quot;Luxembourg&quot;: case &quot;Enclos-St-Laurent&quot;: case &quot;Popincourt&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_cf6d43f8745b7fab84b1b88da14d59b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cf6d43f8745b7fab84b1b88da14d59b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_cf6d43f8745b7fab84b1b88da14d59b3_onEachFeature,
#
#                 style: geo_json_cf6d43f8745b7fab84b1b88da14d59b3_styler,
#         });
#
#         function geo_json_cf6d43f8745b7fab84b1b88da14d59b3_add (data) {
#             geo_json_cf6d43f8745b7fab84b1b88da14d59b3
#                 .addData(data)
#                 .addTo(choropleth_bec061c6686048470f0505442601b898);
#         }
#             geo_json_cf6d43f8745b7fab84b1b88da14d59b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 48.84], [2.351799, 48.83675]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 5, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Panth\u00e9on&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:34.699Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;:

# %%
district_distribution(school_density)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9559eb98f8de9960656e42cb98aff90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9559eb98f8de9960656e42cb98aff90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9559eb98f8de9960656e42cb98aff90 = L.map(
#                 &quot;map_a9559eb98f8de9960656e42cb98aff90&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_534e67fdce36a1823ef6ed9aac5d1e5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9559eb98f8de9960656e42cb98aff90);
#
#
#             var choropleth_0cdc48ea76fdc686d2c90f5b4a6b298e = L.featureGroup(
#                 {}
#             ).addTo(map_a9559eb98f8de9960656e42cb98aff90);
#
#
#         function geo_json_529f752507d65dcb1b3ba3ad066e525c_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Panth\u00e9on&quot;: case &quot;Op\u00e9ra&quot;: case &quot;Buttes-Chaumont&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Luxembourg&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Palais-Bourbon&quot;: case &quot;\u00c9lys\u00e9e&quot;: case &quot;Enclos-St-Laurent&quot;: case &quot;Observatoire&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_529f752507d65dcb1b3ba3ad066e525c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_529f752507d65dcb1b3ba3ad066e525c = L.geoJson(null, {
#                 onEachFeature: geo_json_529f752507d65dcb1b3ba3ad066e525c_onEachFeature,
#
#                 style: geo_json_529f752507d65dcb1b3ba3ad066e525c_styler,
#         });
#
#         function geo_json_529f752507d65dcb1b3ba3ad066e525c_add (data) {
#             geo_json_529f752507d65dcb1b3ba3ad066e525c
#                 .addData(data)
#                 .addTo(choropleth_0cdc48ea76fdc686d2c90f5b4a6b298e);
#         }
#             geo_json_529f752507d65dcb1b3ba3ad066e525c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 48.84], [2.351799, 48.83675]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 5, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Panth\u00e9on&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:34.699Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;co

# %%
airport_normalized
# Out:
#                    Name  Airports  Dog grooming  Basket Court   Schools  \
# 0   Batignolles-Monceau  0.017684      1.000000      0.388977  0.094990
# 1                Bourse  0.369684      0.225999      0.580095  0.000000
# 2      Butte-Montmartre  0.000000      0.993343      0.856463  0.000000
# 3       Buttes-Chaumont  0.088561      0.819902      0.822760  0.317418
# 4              Entrepôt  0.257263      0.384723      0.517446  0.372407
# 5              Gobelins  1.000000      0.046251      0.000000  0.150714
# 6        Hôtel-de-Ville  0.597474      0.241416      0.522601  0.000000
# 7                Louvre  0.450105      0.343378      0.365186  0.000000
# 8            Luxembourg  0.652491      0.865102      0.627280  1.000000
# 9          Ménilmontant  0.422175      0.386826      0.517446  0.000000
# 10         Observatoire  0.938667      0.532586      0.808882  0.383206
# 11                Opéra  0.226105      0.522074      1.000000  0.247132
# 12       Palais-Bourbon  0.501614      0.756833      0.628073  0.395181
# 13             Panthéon  0.747088      0.521374      0.298176  0.211924
# 14                Passy  0.251509      0.148213      0.962331  0.099080
# 15           Popincourt  0.516351      0.251226      0.952815  0.000000
# 16              Reuilly  0.797895      0.526629      0.299762  0.131953
# 17               Temple  0.464281      0.000000      0.457573  0.000000
# 18            Vaugirard  0.670175      0.389629      0.496431  0.000000
# 19               Élysée  0.248842      0.709180      0.442506  0.416259
#
#     Vegan restaurants  Starbucks      Sums
# 0            0.000000   0.098606  1.600258
# 1            1.000000   0.400000  2.575778
# 2            0.000000   0.046545  1.896350
# 3            0.000000   0.000000  2.048641
# 4            0.322153   0.193292  2.047284
# 5            0.000000   0.039113  1.236077
# 6            0.444444   0.600000  2.405935
# 7            0.444444   1.000000  2.603114
# 8            0.216264   0.000000  3.361137
# 9            0.000000   0.000000  1.326447
# 10           0.027625   0.049724  2.740689
# 11           0.427566   0.769619  3.192497
# 12           0.000000   0.068371  2.350071
# 13           0.183327   0.219992  2.181881
# 14           0.000000   0.000000  1.461133
# 15           0.296493   0.076241  2.093127
# 16           0.028537   0.068488  1.853264
# 17           0.444444   0.000000  1.366299
# 18           0.000000   0.164373  1.720609
# 19           0.000000   0.432105  2.248892

# %%
ponderation
# Out:
#                    Name      Sums
# 0   Batignolles-Monceau  1.600258
# 1                Bourse  2.575778
# 2      Butte-Montmartre  1.896350
# 3       Buttes-Chaumont  2.048641
# 4              Entrepôt  2.047284
# 5              Gobelins  1.236077
# 6        Hôtel-de-Ville  2.405935
# 7                Louvre  2.603114
# 8            Luxembourg  3.361137
# 9          Ménilmontant  1.326447
# 10         Observatoire  2.740689
# 11                Opéra  3.192497
# 12       Palais-Bourbon  2.350071
# 13             Panthéon  2.181881
# 14                Passy  1.461133
# 15           Popincourt  2.093127
# 16              Reuilly  1.853264
# 17               Temple  1.366299
# 18            Vaugirard  1.720609
# 19               Élysée  2.248892

# %%
district_distribution(ponderation)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a83121aee1faf36566d64ca50006a00b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a83121aee1faf36566d64ca50006a00b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a83121aee1faf36566d64ca50006a00b = L.map(
#                 &quot;map_a83121aee1faf36566d64ca50006a00b&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_854d3f7100ce1d8f7a9ce5119a1a3d19 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a83121aee1faf36566d64ca50006a00b);
#
#
#             var choropleth_ddedb0f6f60835f08aedee9e33b7b69a = L.featureGroup(
#                 {}
#             ).addTo(map_a83121aee1faf36566d64ca50006a00b);
#
#
#         function geo_json_4e6bcd8093400899ef8fd26f1db93394_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;: case &quot;Palais-Bourbon&quot;: case &quot;Louvre&quot;: case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Panth\u00e9on&quot;: case &quot;\u00c9lys\u00e9e&quot;: case &quot;Popincourt&quot;: case &quot;Buttes-Chaumont&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Luxembourg&quot;: case &quot;Op\u00e9ra&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Enclos-St-Laurent&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Observatoire&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Vaugirard&quot;: case &quot;Batignolles-Monceau&quot;: case &quot;Butte-Montmartre&quot;: case &quot;Reuilly&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4e6bcd8093400899ef8fd26f1db93394_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4e6bcd8093400899ef8fd26f1db93394 = L.geoJson(null, {
#                 onEachFeature: geo_json_4e6bcd8093400899ef8fd26f1db93394_onEachFeature,
#
#                 style: geo_json_4e6bcd8093400899ef8fd26f1db93394_styler,
#         });
#
#         function geo_json_4e6bcd8093400899ef8fd26f1db93394_add (data) {
#             geo_json_4e6bcd8093400899ef8fd26f1db93394
#                 .addData(data)
#                 .addTo(choropleth_ddedb0f6f60835f08aedee9e33b7b69a);
#         }
#             geo_json_4e6bcd8093400899ef8fd26f1db93394_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:0
