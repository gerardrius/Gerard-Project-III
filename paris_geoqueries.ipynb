# %% [markdown]
# From https://github.com/blackmad/neighborhoods/blob/master/paris.geojson we export the geojson code for Paris districts.
#
# Note that the initial raw content would only provide one document when uploaded as a collection in MongoDB Compass. Hence, we followed the second procedure established in troubleshooting section of lectures (https://github.com/Ironhack-data-bcn-january-2023/lectures/blob/main/troubleshooting/importing-into-db/importing-geojsons-into-mongodb.md), and manually removed the first curly brackets pair of the code, in order to maintain only the list with all polygons instead of a multipolygonal dictionary. After that, we successfully uploaded the JSON file to Paris collection in MongoDB.

# %% [markdown]
# # With geojson not including features (imported from Mongo DB)

# %%
# Libraries
from pymongo import MongoClient
import os
import requests
import json
from dotenv import load_dotenv
from bson.json_util import dumps
import pandas as pd
import folium
from folium import Choropleth, Circle, Marker, Icon, Map, TileLayer
from bs4 import BeautifulSoup
import shapely
from shapely import Polygon
from shapely.geometry import shape, Point

from paris_geoqueries import *

# %%
load_dotenv()
# Out:
# True

# %%
# Foursquare key to get API queries.
foursquare_key = os.getenv('fsq_key')

# %%
# Paris collection
client = MongoClient('localhost:27017')
db = client.get_database('ironhack')
paris = db.get_collection('paris')
paris = list(paris.find())

# %%
# Arrondissements scraping:
url = 'https://en.wikipedia.org/wiki/Arrondissements_of_Paris'
html = requests.get(url)
soup = BeautifulSoup(html.content, "html.parser")
table = soup.find_all("table", attrs = {"class":"wikitable"})
arrondissements_info = pd.read_html(table[0].prettify())[0]
arrondissements_info['Area (km  2  )'] = arrondissements_info['Area (km  2  )'].apply(lambda x: x.split(' km')[0])
arrondissements_info
# Out:
#     Coat of arms Arrondissement  (R for  Right Bank  , L for  Left Bank  )  \
# 0            NaN  1st (I  er  )  R  Administratively part of  Pa...
# 1            NaN  2nd (II  e  )  R  Administratively part of  Pa...
# 2            NaN  3rd (III  e  )  R  Administratively part of  P...
# 3            NaN  4th (IV  e  )  R  Administratively part of  Pa...
# 4            NaN                                    5th (V  e  )  L
# 5            NaN                                   6th (VI  e  )  L
# 6            NaN                                  7th (VII  e  )  L
# 7            NaN                                 8th (VIII  e  )  R
# 8            NaN                                   9th (IX  e  )  R
# 9            NaN                                   10th (X  e  )  R
# 10           NaN                                  11th (XI  e  )  R
# 11           NaN                                 12th (XII  e  )  R
# 12           NaN                                13th (XIII  e  )  L
# 13           NaN                                 14th (XIV  e  )  L
# 14           NaN                                  15th (XV  e  )  L
# 15           NaN                                 16th (XVI  e  )  R
# 16           NaN                                17th (XVII  e  )  R
# 17           NaN                               18th (XVIII  e  )  R
# 18           NaN                                 19th (XIX  e  )  R
# 19           NaN                                  20th (XX  e  )  R
#
#                    Name                                     Area (km  2  )  \
# 0                Louvre                           5.59 km  2  (2.16 sq mi)
# 1                Bourse                           5.59 km  2  (2.16 sq mi)
# 2                Temple                           5.59 km  2  (2.16 sq mi)
# 3        Hôtel-de-Ville                           5.59 km  2  (2.16 sq mi)
# 4              Panthéon                         2.541 km  2  (0.981 sq mi)
# 5            Luxembourg                         2.154 km  2  (0.832 sq mi)
# 6        Palais-Bourbon                         4.088 km  2  (1.578 sq mi)
# 7                Élysée                         3.881 km  2  (1.498 sq mi)
# 8                 Opéra                         2.179 km  2  (0.841 sq mi)
# 9              Entrepôt                         2.892 km  2  (1.117 sq mi)
# 10           Popincourt                         3.666 km  2  (1.415 sq mi)
# 11              Reuilly  16.324 km  2  (6.303 sq mi)¹  6.377 km  2  (2....
# 12             Gobelins                         7.146 km  2  (2.759 sq mi)
# 13         Observatoire                         5.621 km  2  (2.170 sq mi)
# 14            Vaugirard                         8.502 km  2  (3.283 sq mi)
# 15                Passy  16.305 km  2  (6.295 sq mi)³  7.846 km  2  (3....
# 16  Batignolles-Monceau                         5.669 km  2  (2.189 sq mi)
# 17     Butte-Montmartre                         6.005 km  2  (2.319 sq mi)
# 18      Buttes-Chaumont                         6.786 km  2  (2.620 sq mi)
# 19         Ménilmontant                         5.984 km  2  (2.310 sq mi)
#
#     Population  (2017 estimate) Density (2017)  (inhabitants per km  2  )  \
# 0                        100196                                     17924
# 1                        100196                                     17924
# 2                        100196                                     17924
# 3                        100196                                     17924
# 4                         59631                                     23477
# 5                         41976                                     19524
# 6                         52193                                     12761
# 7                         37368                                      9631
# 8                         60071                                     27556
# 9                         90836                                     31431
# 10                       147470                                     40183
# 11                       141287                           8,657¹  21,729²
# 12                       183399                                     25650
# 13                       136941                                     24280
# 14                       235178                                     27733
# 15                       149500                         9,169³  19,054  4
# 16                       168737                                     29760
# 17                       196131                                     32634
# 18                       188066                                     27697
# 19                       191800                                     32052
#
#    Peak of population                    Mayor (2020–2026)
# 0         before 1861                 Ariel Weil  (  PS  )
# 1         before 1861                 Ariel Weil  (  PS  )
# 2         before 1861                 Ariel Weil  (  PS  )
# 3         before 1861                 Ariel Weil  (  PS  )
# 4                1911         Florence Berthout  (  DVD  )
# 5                1911          Jean-Pierre Lecoq  (  LR  )
# 6                1926               Rachida Dati  (  LR  )
# 7                1891        Jeanne d'Hauteserre  (  LR  )
# 8                1901           Delphine Bürkli  (  DVD  )
# 9                1881        Alexandra Cordebard  (  PS  )
# 10               1911           François Vauglin  (  PS  )
# 11               1962  Emmanuelle Pierre-Marie  (  EELV  )
# 12            2005  5              Jérôme Coumet  (  PS  )
# 13               1954             Carine Petit  (  Gt.s  )
# 14               1962            Philippe Goujon  (  LR  )
# 15               1962            Francis Szpiner  (  LR  )
# 16               1954           Geoffroy Boulard  (  LR  )
# 17               1931             Éric Lejoindre  (  PS  )
# 18            2005  5           François Dagnaud  (  PS  )
# 19               1936                Éric Pliez  (  DVG  )

# %%
paris
# Out:
# [{'_id': ObjectId('63e7a74af7a1278c06ef1757'),
#   'type': 'Feature',
#   'properties': {'name': 'Bourse',
#    'cartodb_id': 2,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:18.682Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.339999, 48.87196],
#       [2.34789, 48.870689],
#       [2.35433, 48.869308],
#       [2.350979, 48.863411],
#       [2.330292, 48.868294],
#       [2.328211, 48.86972],
#       [2.328072, 48.869923],
#       [2.339999, 48.87196]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1758'),
#   'type': 'Feature',
#   'properties': {'name': 'Temple',
#    'cartodb_id': 3,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:24.060Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.36236, 48.867905],
#       [2.364764, 48.866436],
#       [2.366694, 48.86319],
#       [2.368454, 48.85582],
#       [2.364335, 48.856441],
#       [2.361631, 48.857262],
#       [2.358626, 48.858757],
#       [2.356825, 48.860111],
#       [2.353391, 48.861214],
#       [2.350172, 48.862034],
#       [2.354249, 48.869286],
#       [2.36236, 48.867905]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1759'),
#   'type': 'Feature',
#   'properties': {'name': 'Panthéon',
#    'cartodb_id': 5,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:34.699Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.351799, 48.83675],
#       [2.345489, 48.837601],
#       [2.336462, 48.839622],
#       [2.342576, 48.850258],
#       [2.344199, 48.85376],
#       [2.3445, 48.854038],
#       [2.346859, 48.853298],
#       [2.350169, 48.851997],
#       [2.3548, 48.850788],
#       [2.36098, 48.84861],
#       [2.366, 48.844997],
#       [2.36493, 48.844379],
#       [2.361839, 48.84],
#       [2.351799, 48.83675]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175a'),
#   'type': 'Feature',
#   'properties': {'name': 'Luxembourg',
#    'cartodb_id': 6,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:40.774Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.316469, 48.846851],
#       [2.31904, 48.847851],
#       [2.32412, 48.850311],
#       [2.32704, 48.851608],
#       [2.32866, 48.851952],
#       [2.331599, 48.856339],
#       [2.33386, 48.85918],
#       [2.337499, 48.85849],
#       [2.340592, 48.85675],
#       [2.342512, 48.855247],
#       [2.344465, 48.853992],
#       [2.34425, 48.853767],
#       [2.342639, 48.850349],
#       [2.33652, 48.83963],
#       [2.31999, 48.8451],
#       [2.316469, 48.846851]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175b'),
#   'type': 'Feature',
#   'properties': {'name': 'Palais-Bourbon',
#    'cartodb_id': 7,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:45.091Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.309531, 48.84581],
#       [2.307342, 48.847153],
#       [2.289877, 48.858192],
#       [2.294769, 48.861862],
#       [2.300219, 48.863499],
#       [2.31833, 48.863838],
#       [2.331462, 48.859676],
#       [2.333844, 48.85918],
#       [2.33159, 48.856258],
#       [2.33041, 48.854424],
#       [2.329295, 48.852673],
#       [2.328479, 48.851826],
#       [2.327106, 48.851601],
#       [2.319274, 48.847801],
#       [2.313651, 48.845909],
#       [2.311355, 48.845215],
#       [2.309531, 48.84581]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175c'),
#   'type': 'Feature',
#   'properties': {'name': 'Élysée',
#    'cartodb_id': 8,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:51.084Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.30155, 48.864601],
#       [2.299869, 48.865131],
#       [2.298799, 48.86869],
#       [2.297299, 48.871151],
#       [2.295539, 48.87326],
#       [2.29457, 48.873192],
#       [2.294029, 48.873669],
#       [2.294399, 48.87429],
#       [2.295409, 48.874317],
#       [2.297769, 48.87775],
#       [2.297639, 48.878029],
#       [2.298049, 48.87846],
#       [2.298799, 48.87825],
#       [2.309009, 48.880459],
#       [2.316609, 48.88134],
#       [2.32721, 48.88345],
#       [2.326849, 48.875908],
#       [2.326611, 48.875404],
#       [2.326976, 48.873825],
#       [2.326869, 48.873329],
#       [2.32629, 48.872597],
#       [2.326505, 48.872471],
#       [2.325819, 48.869534],
#       [2.325152, 48.869392],
#       [2.32526, 48.869019],
#       [2.320769, 48.863098],
#       [2.31828, 48.863811],
#       [2.30167, 48.863522],
#       [2.30155, 48.864601]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175d'),
#   'type': 'Feature',
#   'properties': {'name': 'Opéra',
#    'cartodb_id': 9,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:00.221Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.339599, 48.882011],
#       [2.34952, 48.883781],
#       [2.34987, 48.880692],
#       [2.349209, 48.87888],
#       [2.349, 48.87722],
#       [2.348139, 48.87566],
#       [2.34785, 48.873871],
#       [2.34789, 48.870689],
#       [2.34004, 48.87196],
#       [2.32579, 48.869572],
#       [2.326519, 48.872471],
#       [2.326309, 48.872589],
#       [2.32688, 48.873341],
#       [2.326979, 48.873779],
#       [2.32663, 48.875439],
#       [2.32682, 48.87595],
#       [2.32717, 48.883419],
#       [2.327929, 48.883621],
#       [2.32948, 48.884651],
#       [2.337406, 48.882271],
#       [2.339599, 48.882011]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175e'),
#   'type': 'Feature',
#   'properties': {'name': 'Enclos-St-Laurent',
#    'cartodb_id': 10,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:05.756Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.368755, 48.884079],
#       [2.369142, 48.883289],
#       [2.370213, 48.882637],
#       [2.370257, 48.878632],
#       [2.370814, 48.878124],
#       [2.370601, 48.87756],
#       [2.376952, 48.872108],
#       [2.372917, 48.870644],
#       [2.364205, 48.86779],
#       [2.363477, 48.867226],
#       [2.362404, 48.867905],
#       [2.354293, 48.869286],
#       [2.347941, 48.870728],
#       [2.347812, 48.873943],
#       [2.348155, 48.875751],
#       [2.348971, 48.877277],
#       [2.349272, 48.879223],
#       [2.349873, 48.880692],
#       [2.349486, 48.883797],
#       [2.359227, 48.884472],
#       [2.364806, 48.884361],
#       [2.368755, 48.884079]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef175f'),
#   'type': 'Feature',
#   'properties': {'name': 'Popincourt',
#    'cartodb_id': 11,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:14.753Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.383175, 48.867115],
#       [2.383776, 48.86607],
#       [2.387465, 48.862823],
#       [2.389654, 48.858444],
#       [2.39223, 48.857571],
#       [2.394321, 48.856548],
#       [2.398398, 48.85133],
#       [2.399214, 48.848709],
#       [2.399064, 48.848103],
#       [2.395899, 48.848351],
#       [2.384291, 48.85017],
#       [2.379999, 48.850483],
#       [2.371544, 48.852459],
#       [2.370257, 48.853222],
#       [2.369184, 48.853081],
#       [2.366737, 48.86319],
#       [2.36472, 48.866409],
#       [2.363477, 48.867256],
#       [2.364205, 48.86779],
#       [2.376866, 48.872108],
#       [2.383175, 48.867115]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1760'),
#   'type': 'Feature',
#   'properties': {'name': 'Gobelins',
#    'cartodb_id': 13,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:25.726Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.342039, 48.838322],
#       [2.345431, 48.837605],
#       [2.348927, 48.837067],
#       [2.35189, 48.836731],
#       [2.36193, 48.840031],
#       [2.36493, 48.844379],
#       [2.365959, 48.844997],
#       [2.38856, 48.826481],
#       [2.385269, 48.825298],
#       [2.37881, 48.82148],
#       [2.363339, 48.816132],
#       [2.356799, 48.816441],
#       [2.3544, 48.817501],
#       [2.351669, 48.817989],
#       [2.346839, 48.81641],
#       [2.34405, 48.816441],
#       [2.3441, 48.817631],
#       [2.34459, 48.819382],
#       [2.343939, 48.820278],
#       [2.34242, 48.821461],
#       [2.34146, 48.823658],
#       [2.34165, 48.826408],
#       [2.34131, 48.831429],
#       [2.34111, 48.831947],
#       [2.342039, 48.838322]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1761'),
#   'type': 'Feature',
#   'properties': {'name': 'Observatoire',
#    'cartodb_id': 14,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:30.531Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.301464, 48.825428],
#       [2.321032, 48.841503],
#       [2.321547, 48.840996],
#       [2.324594, 48.843651],
#       [2.336396, 48.839695],
#       [2.342105, 48.838284],
#       [2.341117, 48.831982],
#       [2.341504, 48.828793],
#       [2.341632, 48.8256],
#       [2.341504, 48.823254],
#       [2.34249, 48.821304],
#       [2.344036, 48.820118],
#       [2.344551, 48.819355],
#       [2.344164, 48.817574],
#       [2.344078, 48.816502],
#       [2.33571, 48.816811],
#       [2.332878, 48.818478],
#       [2.301464, 48.825428]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1762'),
#   'type': 'Feature',
#   'properties': {'name': 'Vaugirard',
#    'cartodb_id': 15,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:35.322Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.292365, 48.827492],
#       [2.277001, 48.833763],
#       [2.274255, 48.830429],
#       [2.275027, 48.829807],
#       [2.272797, 48.82896],
#       [2.270564, 48.828114],
#       [2.267818, 48.828171],
#       [2.267303, 48.831108],
#       [2.27065, 48.833591],
#       [2.269191, 48.835342],
#       [2.266188, 48.834724],
#       [2.264127, 48.835175],
#       [2.278204, 48.849014],
#       [2.287644, 48.855679],
#       [2.289963, 48.858276],
#       [2.309274, 48.845852],
#       [2.311335, 48.845287],
#       [2.316483, 48.846813],
#       [2.320003, 48.845173],
#       [2.324552, 48.843594],
#       [2.321633, 48.841049],
#       [2.320948, 48.841618],
#       [2.301464, 48.825512],
#       [2.292365, 48.827492]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1763'),
#   'type': 'Feature',
#   'properties': {'name': 'Passy',
#    'cartodb_id': 16,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:40.880Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.28007, 48.878292],
#       [2.294939, 48.873859],
#       [2.297387, 48.871193],
#       [2.299039, 48.868427],
#       [2.29991, 48.865269],
#       [2.301571, 48.864574],
#       [2.3018, 48.863361],
#       [2.29408, 48.86166],
#       [2.28893, 48.85759],
#       [2.28601, 48.854321],
#       [2.277429, 48.847988],
#       [2.26404, 48.835121],
#       [2.257859, 48.835678],
#       [2.253909, 48.839298],
#       [2.25477, 48.845398],
#       [2.2503, 48.845509],
#       [2.241719, 48.848328],
#       [2.2273, 48.84856],
#       [2.225929, 48.85545],
#       [2.23159, 48.86652],
#       [2.23932, 48.870468],
#       [2.2467, 48.876339],
#       [2.25511, 48.874199],
#       [2.258199, 48.88052],
#       [2.28007, 48.878292]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1764'),
#   'type': 'Feature',
#   'properties': {'name': 'Batignolles-Monceau',
#    'cartodb_id': 17,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:46.239Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.27999, 48.878361],
#       [2.28325, 48.882771],
#       [2.29185, 48.88842],
#       [2.29768, 48.889648],
#       [2.306185, 48.895111],
#       [2.314081, 48.898159],
#       [2.32188, 48.900612],
#       [2.33013, 48.900799],
#       [2.32562, 48.887589],
#       [2.32721, 48.88345],
#       [2.31691, 48.881302],
#       [2.30867, 48.880402],
#       [2.29807, 48.878151],
#       [2.29502, 48.873909],
#       [2.27999, 48.878361]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1765'),
#   'type': 'Feature',
#   'properties': {'name': 'Butte-Montmartre',
#    'cartodb_id': 18,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:52.398Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.370379, 48.900719],
#       [2.370379, 48.896709],
#       [2.37184, 48.895359],
#       [2.370289, 48.894459],
#       [2.367081, 48.887592],
#       [2.36663, 48.886604],
#       [2.36472, 48.884411],
#       [2.358789, 48.884411],
#       [2.34952, 48.883678],
#       [2.339739, 48.88187],
#       [2.337254, 48.882286],
#       [2.32953, 48.88443],
#       [2.32792, 48.883526],
#       [2.327192, 48.883415],
#       [2.325603, 48.887619],
#       [2.33021, 48.900829],
#       [2.353209, 48.901279],
#       [2.370379, 48.900719]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1766'),
#   'type': 'Feature',
#   'properties': {'name': 'Buttes-Chaumont',
#    'cartodb_id': 19,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:58.058Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.408749, 48.877857],
#       [2.402309, 48.875999],
#       [2.395255, 48.875259],
#       [2.39021, 48.875549],
#       [2.387719, 48.874531],
#       [2.386519, 48.874649],
#       [2.38472, 48.873859],
#       [2.376819, 48.872219],
#       [2.370379, 48.87809],
#       [2.37021, 48.882771],
#       [2.36892, 48.883339],
#       [2.368669, 48.884132],
#       [2.364742, 48.884403],
#       [2.366781, 48.886688],
#       [2.368348, 48.890202],
#       [2.370289, 48.894508],
#       [2.37175, 48.89547],
#       [2.370279, 48.896648],
#       [2.370379, 48.90078],
#       [2.3769, 48.900269],
#       [2.38849, 48.900661],
#       [2.392009, 48.899818],
#       [2.39381, 48.898239],
#       [2.39725, 48.88588],
#       [2.401879, 48.88176],
#       [2.4066, 48.880119],
#       [2.408749, 48.877857]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1767'),
#   'type': 'Feature',
#   'properties': {'name': 'Louvre',
#    'cartodb_id': 1,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:13.177Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.320769, 48.863037],
#       [2.325229, 48.868938],
#       [2.325149, 48.869419],
#       [2.328018, 48.869949],
#       [2.330302, 48.868286],
#       [2.350944, 48.863407],
#       [2.347351, 48.857124],
#       [2.34691, 48.856972],
#       [2.345966, 48.855373],
#       [2.344529, 48.854012],
#       [2.3424, 48.855247],
#       [2.340469, 48.8568],
#       [2.33725, 48.858467],
#       [2.331459, 48.85968],
#       [2.320769, 48.863037]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1768'),
#   'type': 'Feature',
#   'properties': {'name': 'Hôtel-de-Ville',
#    'cartodb_id': 4,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:36:29.259Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.36465, 48.845989],
#       [2.360899, 48.84864],
#       [2.35467, 48.850849],
#       [2.35013, 48.851978],
#       [2.34695, 48.853298],
#       [2.344551, 48.854027],
#       [2.345966, 48.855396],
#       [2.346986, 48.856964],
#       [2.347329, 48.857147],
#       [2.350169, 48.86203],
#       [2.353299, 48.86124],
#       [2.35678, 48.860161],
#       [2.358579, 48.858749],
#       [2.36167, 48.857258],
#       [2.364329, 48.856407],
#       [2.36836, 48.855869],
#       [2.3692, 48.85281],
#       [2.366299, 48.846958],
#       [2.36465, 48.845989]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef1769'),
#   'type': 'Feature',
#   'properties': {'name': 'Reuilly',
#    'cartodb_id': 12,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:37:20.571Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.414499, 48.846809],
#       [2.41252, 48.836529],
#       [2.409609, 48.83427],
#       [2.41407, 48.833698],
#       [2.42214, 48.83585],
#       [2.420249, 48.840588],
#       [2.419299, 48.84206],
#       [2.419989, 48.84359],
#       [2.42179, 48.844547],
#       [2.42445, 48.841778],
#       [2.438359, 48.840588],
#       [2.43922, 48.844547],
#       [2.44085, 48.84444],
#       [2.44076, 48.845959],
#       [2.4466, 48.845901],
#       [2.44634, 48.84494],
#       [2.455519, 48.844097],
#       [2.46334, 48.842232],
#       [2.46977, 48.836529],
#       [2.46909, 48.834148],
#       [2.465219, 48.831497],
#       [2.46428, 48.827599],
#       [2.466, 48.827259],
#       [2.464789, 48.822968],
#       [2.462559, 48.819458],
#       [2.45887, 48.81715],
#       [2.453889, 48.816978],
#       [2.44857, 48.818157],
#       [2.4375, 48.818439],
#       [2.43733, 48.81963],
#       [2.431919, 48.822628],
#       [2.42763, 48.82415],
#       [2.421959, 48.824211],
#       [2.419729, 48.8241],
#       [2.41733, 48.8246],
#       [2.41107, 48.825001],
#       [2.40669, 48.826981],
#       [2.403509, 48.8293],
#       [2.40111, 48.829689],
#       [2.39562, 48.828049],
#       [2.390719, 48.827198],
#       [2.38858, 48.826469],
#       [2.364539, 48.84613],
#       [2.366429, 48.847031],
#       [2.36918, 48.85313],
#       [2.370379, 48.85313],
#       [2.371544, 48.852417],
#       [2.38017, 48.850368],
#       [2.384459, 48.850079],
#       [2.39596, 48.848328],
#       [2.414499, 48.846809]]]]}},
#  {'_id': ObjectId('63e7a74af7a1278c06ef176a'),
#   'type': 'Feature',
#   'properties': {'name': 'Ménilmontant',
#    'cartodb_id': 20,
#    'created_at': '2013-02-26T07:07:16.384Z',
#    'updated_at': '2013-02-26T18:38:05.143Z'},
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[2.4133, 48.865269],
#       [2.41414, 48.859051],
#       [2.41398, 48.853809],
#       [2.414675, 48.852573],
#       [2.41527, 48.851028],
#       [2.41441, 48.846802],
#       [2.39904, 48.848099],
#       [2.3993, 48.848789],
#       [2.39835, 48.851261],
#       [2.39441, 48.856522],
#       [2.38965, 48.858471],
#       [2.38737, 48.862961],
#       [2.3835, 48.866169],
#       [2.38319, 48.867142],
#       [2.37682, 48.872231],
#       [2.38497, 48.873959],
#       [2.38651, 48.874691],
#       [2.38789, 48.874531],
#       [2.39037, 48.875542],
#       [2.39529, 48.87521],
#       [2.40221, 48.87595],
#       [2.40858, 48.87785],
#       [2.41097, 48.87431],
#       [2.41338, 48.87109],
#       [2.4133, 48.865269]]]]}}]

# %%
district_list = [paris[i]['properties']['name'] for i in range(len(paris))]
print(district_list)
# Out:
# ['Bourse', 'Temple', 'Panthéon', 'Luxembourg', 'Palais-Bourbon', 'Élysée', 'Opéra', 'Enclos-St-Laurent', 'Popincourt', 'Gobelins', 'Observatoire', 'Vaugirard', 'Passy', 'Batignolles-Monceau', 'Butte-Montmartre', 'Buttes-Chaumont', 'Louvre', 'Hôtel-de-Ville', 'Reuilly', 'Ménilmontant']

# %%
# Feature geojson is the one used to plot
with open('feature.geojson') as geo_file:
    geo_feature = json.load(geo_file)

# %% [markdown]
# # ON THE MAP, AFTER MAKING SOME DATAFRAME WITH VARIABLES AND FREQUENCIES AND DEFINING THE PONDERATION, PLOT COLORED DISTRICTS WITH SOME SCALE!

# %%
paris_map = Map(location = [48.86, 2.35], zoom_start = 11)
folium.Choropleth(
    geo_data=geo_feature,
    key_on="feature.properties.name",
).add_to(paris_map)
paris_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d1541ecaed024106eb797c1891d511e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d1541ecaed024106eb797c1891d511e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d1541ecaed024106eb797c1891d511e = L.map(
#                 &quot;map_5d1541ecaed024106eb797c1891d511e&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99fab126f85fdcc4e441a0c12c6d0380 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d1541ecaed024106eb797c1891d511e);
#
#
#             var choropleth_45748a355a8ae5cf0501692d603d1a8f = L.featureGroup(
#                 {}
#             ).addTo(map_5d1541ecaed024106eb797c1891d511e);
#
#
#         function geo_json_c161bb50bff718bae7de09680c4a4bbe_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c161bb50bff718bae7de09680c4a4bbe_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c161bb50bff718bae7de09680c4a4bbe = L.geoJson(null, {
#                 onEachFeature: geo_json_c161bb50bff718bae7de09680c4a4bbe_onEachFeature,
#
#                 style: geo_json_c161bb50bff718bae7de09680c4a4bbe_styler,
#         });
#
#         function geo_json_c161bb50bff718bae7de09680c4a4bbe_add (data) {
#             geo_json_c161bb50bff718bae7de09680c4a4bbe
#                 .addData(data)
#                 .addTo(choropleth_45748a355a8ae5cf0501692d603d1a8f);
#         }
#             geo_json_c161bb50bff718bae7de09680c4a4bbe_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 48.84], [2.351799, 48.83675]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 5, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Panth\u00e9on&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:34.699Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.316469, 48.846851], [2.31904, 48.847851], [2.32412, 48.850311], [2.32704, 48.851608], [2.32866, 48.851952], [2.331599, 48.856339], [2.33386, 48.85918], [2.337499, 48.85849], [2.340592, 48.85675], [2.342512, 48.855247], [2.344465, 48.853992], [2.34425, 48.853767], [2.342639, 48.850349], [2.33652, 48.83963], [2.31999, 48.8451], [2.316469, 48.846851]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 6, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Luxembourg&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:40.774Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.309531, 48.84581], [2.307342, 48.847153], [2.289877, 48.858192], [2.294769, 48.861862], [2.300219, 48.863499], [2.31833, 48.863838], [2.331462, 48.859676], [2.333844, 48.85918], [2.33159, 48.856258], [2.33041, 48.854424], [2.329295, 48.852673], [2.3

# %% [markdown]
# # FOURSQUARE API REQUESTS!!!
# WILL PROVIDE SOME COORDINATES THAT WILL HAVE TO BE PASSED TO DISTRICT CHECKER!

# %%
def foursquare_query (query, place, limit=10):
    url = f"https://api.foursquare.com/v3/places/search?query={query}&near={place}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": foursquare_key
    }

    # full response
    response = requests.get(url, headers=headers).json()['results']
    # name of the establishment
    response[0]['name']
    # coordinates
    response[0]['geocodes']['main']['latitude']
    response[0]['geocodes']['main']['longitude']

    request_points = []
    for i in range(len(response)):
        request_points.append(Point(response[i]['geocodes']['main']['longitude'], response[i]['geocodes']['main']['latitude']))

    d = {'Coordinates': request_points, 'Name': response[i]['name'], 'Type': response[i]['categories'][0]['name']}
    df = pd.DataFrame(data=d)
    return df

# %%
foursquare_query('Starbucks', 'Paris', 2)
# Out:
#                   Coordinates       Name         Type
# 0  POINT (2.354761 48.856877)  Starbucks  Coffee Shop
# 1  POINT (2.348125 48.858843)  Starbucks  Coffee Shop

# %%
dogs = foursquare_query('Dog hairdresser', 'Paris', 5)

# %%
party = foursquare_query('Party clubs', 'Paris', 50)

# %%
party
# Out:
#                    Coordinates                                         Name  \
# 0   POINT (2.344213 48.864026)  Federation Francoph des Clubs Pyramide Ffcp
# 1   POINT (2.353804 48.845937)  Federation Francoph des Clubs Pyramide Ffcp
# 2   POINT (2.375769 48.853512)  Federation Francoph des Clubs Pyramide Ffcp
# 3    POINT (2.28846 48.876257)  Federation Francoph des Clubs Pyramide Ffcp
# 4   POINT (2.388956 48.896342)  Federation Francoph des Clubs Pyramide Ffcp
# 5   POINT (2.347822 48.851513)  Federation Francoph des Clubs Pyramide Ffcp
# 6   POINT (2.303828 48.902613)  Federation Francoph des Clubs Pyramide Ffcp
# 7   POINT (2.361356 48.853002)  Federation Francoph des Clubs Pyramide Ffcp
# 8   POINT (2.346487 48.871101)  Federation Francoph des Clubs Pyramide Ffcp
# 9   POINT (2.368574 48.867735)  Federation Francoph des Clubs Pyramide Ffcp
# 10  POINT (2.346006 48.834064)  Federation Francoph des Clubs Pyramide Ffcp
# 11    POINT (2.33183 48.86937)  Federation Francoph des Clubs Pyramide Ffcp
# 12  POINT (2.335992 48.834043)  Federation Francoph des Clubs Pyramide Ffcp
# 13  POINT (2.348011 48.877097)  Federation Francoph des Clubs Pyramide Ffcp
# 14  POINT (2.384713 48.843588)  Federation Francoph des Clubs Pyramide Ffcp
# 15  POINT (2.306001 48.846346)  Federation Francoph des Clubs Pyramide Ffcp
# 16  POINT (2.371591 48.827906)  Federation Francoph des Clubs Pyramide Ffcp
# 17  POINT (2.358264 48.823931)  Federation Francoph des Clubs Pyramide Ffcp
# 18  POINT (2.315999 48.874546)  Federation Francoph des Clubs Pyramide Ffcp
# 19    POINT (2.37234 48.82407)  Federation Francoph des Clubs Pyramide Ffcp
# 20   POINT (2.254324 48.92327)  Federation Francoph des Clubs Pyramide Ffcp
# 21  POINT (2.302145 48.873273)  Federation Francoph des Clubs Pyramide Ffcp
# 22      POINT (2.337 48.88922)  Federation Francoph des Clubs Pyramide Ffcp
# 23      POINT (2.39703 48.832)  Federation Francoph des Clubs Pyramide Ffcp
# 24  POINT (2.289406 48.866592)  Federation Francoph des Clubs Pyramide Ffcp
# 25    POINT (2.28329 48.85432)  Federation Francoph des Clubs Pyramide Ffcp
# 26  POINT (2.391929 48.887818)  Federation Francoph des Clubs Pyramide Ffcp
# 27  POINT (2.288712 48.881187)  Federation Francoph des Clubs Pyramide Ffcp
# 28  POINT (2.296222 48.818722)  Federation Francoph des Clubs Pyramide Ffcp
# 29  POINT (2.399762 48.791401)  Federation Francoph des Clubs Pyramide Ffcp
#
#             Type
# 0   Organization
# 1   Organization
# 2   Organization
# 3   Organization
# 4   Organization
# 5   Organization
# 6   Organization
# 7   Organization
# 8   Organization
# 9   Organization
# 10  Organization
# 11  Organization
# 12  Organization
# 13  Organization
# 14  Organization
# 15  Organization
# 16  Organization
# 17  Organization
# 18  Organization
# 19  Organization
# 20  Organization
# 21  Organization
# 22  Organization
# 23  Organization
# 24  Organization
# 25  Organization
# 26  Organization
# 27  Organization
# 28  Organization
# 29  Organization

# %% [markdown]
# # IMPORTANT PIECE OF CODE: CHECK IF A POINT BELONGS TO A DISTRICT!!!

# %%
def spot_finder (df): # accepts as much df as variables of interest for the new office location.
    '''
    Function that counts instances per district in Paris.
    Takes the dataframe obtained in the 4 square geoquery
    Returns a dictionary with the count of establishments per district.
    '''

    # We append the list of districts as keys in a dict, and set a default value of 0 for each key.
    district_list = [paris[i]['properties']['name'] for i in range(len(paris))]
    dict_count = {}
    for i in district_list:
        dict_count[i] = 0

    with open('feature.geojson') as geo_file:
        geo_feature = json.load(geo_file)

    # Iteration through each pair of coordinates to see what Paris district they match, being districts defined in geo_feature file.
    for establishment in df['Coordinates']:
        for feature in geo_feature['features']:
            polygon = shape(feature['geometry'])
            if polygon.contains(establishment):
                # Addition to the correspondent district in case the coordinate matches.
                if feature["properties"]["name"] in dict_count:
                    dict_count[feature["properties"]["name"]] += 1

    count_df = pd.DataFrame.from_dict(dict_count, orient="index").reset_index(drop=False)
    count_df.rename(columns={'index': 'District', 0: 'Count'}, inplace=True, errors='raise')

    return count_df

# %%
party_district_distribution = spot_finder (party)
party_district_distribution
# Out:
#                District  Count
# 0                Bourse      1
# 1                Temple      0
# 2              Panthéon      2
# 3            Luxembourg      0
# 4        Palais-Bourbon      0
# 5                Élysée      2
# 6                 Opéra      2
# 7     Enclos-St-Laurent      0
# 8            Popincourt      2
# 9              Gobelins      4
# 10         Observatoire      1
# 11            Vaugirard      1
# 12                Passy      2
# 13  Batignolles-Monceau      2
# 14     Butte-Montmartre      1
# 15      Buttes-Chaumont      2
# 16               Louvre      1
# 17       Hôtel-de-Ville      1
# 18              Reuilly      2
# 19         Ménilmontant      0

# %%
# Feature geojson is the one used to plot
def district_distribution (count_df):
    '''
    Function that plots the establishments distribution in Paris' districts.
    Takes the count dataframe obtained in the function above, with the count of establishments per district
    Returns the map plot of this distribution.
    '''
    paris_map = Map(location = [48.86, 2.35], zoom_start = 11)
    folium.Choropleth(
        geo_data=geo_feature,
        data=count_df,
        columns=count_df.columns,
        key_on="feature.properties.name",
    ).add_to(paris_map)
    
    return paris_map

# %%
district_distribution(party_district_distribution)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eacaef973128b8845ba4db77a4f26c42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eacaef973128b8845ba4db77a4f26c42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eacaef973128b8845ba4db77a4f26c42 = L.map(
#                 &quot;map_eacaef973128b8845ba4db77a4f26c42&quot;,
#                 {
#                     center: [48.86, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9d978090eeda13ceef1411e1f8954ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eacaef973128b8845ba4db77a4f26c42);
#
#
#             var choropleth_ff48307350946958c6a6797642c02093 = L.featureGroup(
#                 {}
#             ).addTo(map_eacaef973128b8845ba4db77a4f26c42);
#
#
#         function geo_json_6760487c42cacd28ba507b6cd3ab21e4_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Bourse&quot;: case &quot;Observatoire&quot;: case &quot;Vaugirard&quot;: case &quot;Butte-Montmartre&quot;: case &quot;Louvre&quot;: case &quot;H\u00f4tel-de-Ville&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Temple&quot;: case &quot;Luxembourg&quot;: case &quot;Palais-Bourbon&quot;: case &quot;Enclos-St-Laurent&quot;: case &quot;M\u00e9nilmontant&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Gobelins&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6760487c42cacd28ba507b6cd3ab21e4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6760487c42cacd28ba507b6cd3ab21e4 = L.geoJson(null, {
#                 onEachFeature: geo_json_6760487c42cacd28ba507b6cd3ab21e4_onEachFeature,
#
#                 style: geo_json_6760487c42cacd28ba507b6cd3ab21e4_styler,
#         });
#
#         function geo_json_6760487c42cacd28ba507b6cd3ab21e4_add (data) {
#             geo_json_6760487c42cacd28ba507b6cd3ab21e4
#                 .addData(data)
#                 .addTo(choropleth_ff48307350946958c6a6797642c02093);
#         }
#             geo_json_6760487c42cacd28ba507b6cd3ab21e4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.339999, 48.87196], [2.34789, 48.870689], [2.35433, 48.869308], [2.350979, 48.863411], [2.330292, 48.868294], [2.328211, 48.86972], [2.328072, 48.869923], [2.339999, 48.87196]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 2, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Bourse&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:18.682Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.36236, 48.867905], [2.364764, 48.866436], [2.366694, 48.86319], [2.368454, 48.85582], [2.364335, 48.856441], [2.361631, 48.857262], [2.358626, 48.858757], [2.356825, 48.860111], [2.353391, 48.861214], [2.350172, 48.862034], [2.354249, 48.869286], [2.36236, 48.867905]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 3, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Temple&quot;, &quot;updated_at&quot;: &quot;2013-02-26T18:36:24.060Z&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.351799, 48.83675], [2.345489, 48.837601], [2.336462, 48.839622], [2.342576, 48.850258], [2.344199, 48.85376], [2.3445, 48.854038], [2.346859, 48.853298], [2.350169, 48.851997], [2.3548, 48.850788], [2.36098, 48.84861], [2.366, 48.844997], [2.36493, 48.844379], [2.361839, 48.84], [2.351799, 48.83675]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;cartodb_id&quot;: 5, &quot;created_at&quot;: &quot;2013-02-26T07:07:16.384Z&quot;, &quot;name&quot;: &quot;Panth\u00e9on&quot;, &quot;updated_at&quot;: &q
